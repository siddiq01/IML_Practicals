# %%
# 216270307034
# Siddiq Badlani

import numpy as np # linear algebra

arr = np.array(np.arange(14))
# arr = np.arange(14)
new_arr = np.array_split(arr, (2, 6))
print(arr)
print(new_arr)
print(type(arr))
print(type(new_arr))

# %%
arr1 = np.array([1, 2, 3])
print("First array:", arr1)

arr2 = np.array([4, 5, 6])
print("First array:", arr2)

arr3 = np.hstack([arr1, arr2])
print("Horizontal view:\n", arr3)

arr3 = np.vstack([arr1, arr2])
print("Vertical view:\n", arr3)
